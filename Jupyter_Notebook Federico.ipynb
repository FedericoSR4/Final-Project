# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# <B> Federico De Rosa </B>
#
# Tester

# %% [markdown]
# <I> I am interested in Data Science because I started to work for Capgemini as Software Tester but I would like to increase my knoledges in many fields. </I>

# %% [markdown]
# <h3> In the next row I will calculate how many hours there are in a week. </h3>

# %%
# Hours during a week
d = 24
w = 7
tot_week = d * w
print("Ore totali in una settimana =")
tot_week
# Out:
# Ore totali in una settimana =
# 168

# %% [markdown]
# [By the following link you can reach google] (www.google.it)
# In Google you can:
# 1. Research online websites
# 2. Study online
# 3. Attempt classes
# 4. etc...
#
# <h3> Serie A standings: </h3>
#
# | Team | Pts | W | D | L |
# | ------ | --- | --- | --- | --- |
# | Napoli | 14 | 4 | 2 | 0 |
# | Milan | 14 | 4 | 2 | 0 |
# | Udinese | 13 | 4 | 1 | 1 |
